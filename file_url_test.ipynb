# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-hogehoge/German-Drugstore-dm-Facial-Serum-Analysis/blob/main/file_url_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. GitHub上のRawファイルURL（※ご自身のアカウント名・リポジトリ名に書き換えてください）
github_raw_url = "https://github.com/yuki-hogehoge/German-Drugstore-dm-Facial-Serum-Analysis/blob/main/data/skincare_dataset_dm_serum_top30.csv"

# 2. フォールバック（バックアップ）付きのデータ読み込み処理
try:
    # まずGitHubのURLから読み込む（誰でも・どの環境でも動作します）
    df = pd.read_csv(github_raw_url, encoding='utf-8-sig')
    print("✅ Successfully loaded dataset from GitHub Raw URL!")
except Exception as e:

    print(f"⚠️ 読み込めず")

# データの先頭を確認
df.head(3)
